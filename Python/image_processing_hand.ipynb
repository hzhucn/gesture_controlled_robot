# %%
import cv2
import matplotlib.pyplot as plt
from numpy import uint8, ones
from os import listdir
from os.path import isfile, join
path = '../DATA/STOP/'
files = [path+f for f in listdir(path) if isfile(join(path, f))]

# %%
img_bgr= cv2.imread(files[0])
h,w =img_bgr.shape[:2]
print(h,w)

img_rgb = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

#convert to grayscale 
gray = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2GRAY)

# Blur an image 
blur=cv2.GaussianBlur(img_rgb,(0,0),5)

#detect feature points
kaze =  cv2.xfeatures2d.SURF
(kps, descs) = kaze.detectAndCompute(img, None)
print("# kps: {}, descriptors: {}".format(len(kps), descs.shape))
mask=uint8(ones(gray.shape))
keypoints=kaze.detect(gray,mask)

#show image and points
for k in keypoints[::10]:
    cv2.circle(img_bgr,(int(k.pt[0]),int(k.pt[1])),2,(0,255,0),-1)
    cv2.circle(img_bgr,(int(k.pt[0]),int(k.pt[1])),int(k.size),(0,255,0),2)
img2 = cv2.drawKeypoints(img,kps,None,(255,0,0),4)

plt.imshow(img2)
plt.show()
# Out:
# (480, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4573d19398ed> in <module>()
#      14
#      15 #detect feature points
# ---> 16 kaze =  cv2.SURF()
#      17 (kps, descs) = kaze.detectAndCompute(img, None)
#      18 print("# kps: {}, descriptors: {}".format(len(kps), descs.shape))
#
# AttributeError: 'module' object has no attribute 'SURF'

# %%
help(cv2.xfeatures2d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-34550007436a> in <module>()
# ----> 1 help(cv2.xfeatures2d)
#
# AttributeError: 'module' object has no attribute 'xfeatures2d'
